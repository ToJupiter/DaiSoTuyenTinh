# %% [markdown]
# <div>
# <img src="Images/P1/image.png" width="500"/>
# </div>
#
# Mot ngay moi lai den. Giua canh rung gia, chu gau nau bat dau mot hanh trinh moi.

# %% [markdown]
# <div>
# <img src="Images/P1/i1.png" width="500"/>
# </div>
#
# Dưới ánh nắng vàng ươm, chú gấu nhỏ líu lo tiến về phía cây táo sai trĩu quả. Trong đầu chú văng vẳng giọng nói của mẹ: "Nhớ nhé con, đi thẳng 3 bước, rẽ trái 2 bước, rẽ phải 5 bước là tới nơi! Hãy nhớ nhà là nơi bắt đầu - toạ độ $ \langle 0, 0 \rangle $"
#
# $$ \vec{v_{tổng}} = \vec{v_1} + \vec{v_2} + \vec{v_3} $$
# $$ \vec{v_{tổng}} = \langle 3, 0 \rangle + \langle 0, 2 \rangle + \langle 5, 0 \rangle $$
# $$ \vec{v_{tổng}} = \langle 3+0+5, 0+2+0 \rangle $$
# $$ \vec{v_{tổng}} = \langle 8, 2 \rangle $$
